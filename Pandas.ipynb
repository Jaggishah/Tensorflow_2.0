# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaggishah/Tensorflow_2.0/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
series = pd.Series(['Jaggi','Shah','Good'])
series
# Out:
# 0    Jaggi
# 1     Shah
# 2     Good
# dtype: object

# %%
Colour = pd.Series(['Red','Black','Blue'])
Colour
# Out:
# 0      Red
# 1    Black
# 2     Blue
# dtype: object

# %%
car_data = pd.DataFrame({"Car make": series, "Colour":Colour})
car_data
# Out:
#   Car make Colour
# 0    Jaggi    Red
# 1     Shah  Black
# 2     Good   Blue

# %%
#import data
car_sales = pd.read_csv('car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
 car_sales['Doors'].sum()
# Out:
# 40

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
animal = pd.Series(['jaggi','shah','denowal'],index=[0,5,6])
animal
# Out:
# 0      jaggi
# 5       shah
# 6    denowal
# dtype: object

# %%
animal.loc[5]
# Out:
# 'shah'

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.loc[:2]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales[car_sales["Make"]=="Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(["Make"]).mean()
# Out:
# <ipython-input-23-b0a0096139ad>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   car_sales.groupby(["Make"]).mean()
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales["Doors"].plot()
# Out:
# <Axes: >

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','').astype(int)
# Out:
# <ipython-input-25-bc3aa36a54af>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','').astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
car_sales_missing = pd.read_csv('car-sales-missing-data.csv')
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales['Odometer (KM)'].mean())
# Out:
# 0    150043.0
# 1     87899.0
# 2     78601.4
# 3     11179.0
# 4    213095.0
# 5     78601.4
# 6     78601.4
# 7     78601.4
# 8     60000.0
# 9     31600.0
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales['Odometer (KM)'].mean(),inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue   78601.4    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green   78601.4    4.0   $4,500
# 6   Honda    NaN   78601.4    4.0   $7,500
# 7   Honda   Blue   78601.4    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue   78601.4    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green   78601.4    4.0   $4,500

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue   78601.4    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green   78601.4    4.0   $4,500
# 6   Honda    NaN   78601.4    4.0   $7,500
# 7   Honda   Blue   78601.4    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing.to_csv("car-sales-dropping.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue   78601.4    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green   78601.4    4.0   $4,500

# %%
sales = pd.Series([4,5,6,6])
car_sales_missing['Sales'] = sales

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price  Sales
# 0  Toyota  White  150043.0    4.0   $4,000    4.0
# 1   Honda    Red   87899.0    4.0   $5,000    5.0
# 2  Toyota   Blue   78601.4    3.0   $7,000    6.0
# 3     BMW  Black   11179.0    5.0  $22,000    6.0
# 4  Nissan  White  213095.0    4.0   $3,500    NaN
# 5  Toyota  Green   78601.4    4.0   $4,500    NaN

# %%
car_sales_missing.fillna(5,inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price  Sales
# 0  Toyota  White  150043.0    4.0   $4,000    4.0
# 1   Honda    Red   87899.0    4.0   $5,000    5.0
# 2  Toyota   Blue   78601.4    3.0   $7,000    6.0
# 3     BMW  Black   11179.0    5.0  $22,000    6.0
# 4  Nissan  White  213095.0    4.0   $3,500    5.0
# 5  Toyota  Green   78601.4    4.0   $4,500    5.0

# %%
car_sales_missing['Sales'] = car_sales_missing['Sales'].apply(lambda x : x+4)
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price  Sales
# 0  Toyota  White  150043.0    4.0   $4,000    8.0
# 1   Honda    Red   87899.0    4.0   $5,000    9.0
# 2  Toyota   Blue   78601.4    3.0   $7,000   10.0
# 3     BMW  Black   11179.0    5.0  $22,000   10.0
# 4  Nissan  White  213095.0    4.0   $3,500    9.0
# 5  Toyota  Green   78601.4    4.0   $4,500    9.0
